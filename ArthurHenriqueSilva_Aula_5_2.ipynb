# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 5.2

print('Esse programa é referente à aula 5.2 de python da uerj 2021/01')

print(' ')
print(' ')

input("Pressione Enter para continuar!")

print(' ')
print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('Escreva uma função chamada square, que toma um parâmetro t, que é uma')
print('Turtle. Essa função deve usar o turtle para desenhar um quadrado. Escreva')
print('uma chamada de função que passe joana como argumento para square e rode o')
print('programa novamente.')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

def square (t):
  joana.up()
  t.left(180)
  t.forward(50)
  t.left(90)
  t.forward(50)
  t.left(90)
  t.down()

  for i in range(4):
    t.forward(100)
    t.left(90)
  
  joana.up()
  t.left(90)
  t.forward(50)
  t.right(90)
  t.forward(50)
  t.down()
  
square(joana)

jn.mainloop()            

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Adicione um outro parâmetro, chamado length, à função square. Modifique o')
print('corpo da função de tal forma que o comprimento dos lados do quadrado seja')
print('length e então modifique a chamada da função para que seja passado o') 
print('segundo argumento. Rode o programa novamente. Teste o seu programa com')
print('diversos valores para length.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

def square (t, length):
  joana.up()
  t.left(180)
  t.forward(length/2)
  t.left(90)
  t.forward(length/2)
  t.left(90)
  t.down()

  for i in range(4):
    t.forward(length)
    t.left(90)
  
  joana.up()
  t.left(90)
  t.forward(length/2)
  t.right(90)
  t.forward(length/2)
  t.down()
  
square(joana, 250)
jn.mainloop()                    

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 3

print('Exercício 3')

print(' ')

print('Faça uma cópia da função square e mude o nome para polygon. Adicione um') 
print('outro parâmetro chamado n e modifique o corpo da função para que ela')
print('desenhe um polígono regular de n lados. Dica: Os ângulos externos de um') 
print('polígono regular de n lados são de 360/n graus.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

def polygon (t, n, length):
  
  a = (length/2)/math.tan(math.pi/n)
  
  joana.up()
  t.left(180)
  t.forward(length/2)
  t.left(90)
  t.forward(a)
  t.left(90)
  t.down()

  for i in range(n):
    t.forward(length)
    t.left(360/n)
  
  joana.up()
  t.left(90)
  t.forward(a)
  t.right(90)
  t.forward(length/2)
  t.down()
  
polygon(joana, 10, 75)
jn.mainloop()                 

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 4

print('Exercício 4')

print(' ')

print('Escreva uma função chamada circle que toma como argumento uma Turtle, t,')
print('e um raio, r, e desenha um círculo aproximado ao chamar a função polygon') 
print('com length e número n de lados apropriados. Teste sua função com um')
print('intervalo de valores de r. Dica: Determine a circunferência do círculo e')
print('se certifique que comprimento * n = circunferência.')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

def circle (t, r, n):
  
  joana.up()
  t.right(90)
  t.forward(r)
  t.left(90)
  t.down()
  

  for i in range(n):
    t.left(360/n)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/n))))
  
  joana.up()
  t.left(90)
  t.forward(r)
  t.right(90)
  t.down()
  
circle(joana, 200, 200)
jn.mainloop()

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 5

print('Exercício 5')

print(' ')

print('Faça uma versão mais geral da função circle, chamada arc, que toma um')
print('parâmetro adicional, angle, que determina qual a fração do circulo a ser')
print('desenhada. angle está em unidades de graus, logo quando angle=360, a')
print('função arc deve desenhar um cículo completo.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

def circle (t, r, ang):

  for i in range(ang):
    t.left(1)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/360))))
  
  
circle(joana, 50, 90)
jn.mainloop()

print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
