# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print()

print('Aluno - Arthur Henrique Silva')
print('Aula - 5')

print()

# !pip3 install ColabTurtle

import ColabTurtle 
import ColabTurtle.Turtle as T
import math as mt 

#t é o nome da tartaruga
#n é o número de lados
#length é o comprimento

def polyline(t, n, length, angle):
    """Draws n line segments with the given length and
    angle (in degrees) between them.  t is a turtle.
    """    
    for i in range(n):
        t.forward(int(length))
        t.left(angle)

def polygon(t, n, length): 
    angle = 360.0 / n 
    polyline(t, n, length, angle)

def arc(t, r, angle):
    arc_length = 2 * mt.pi * r * angle / 360
    n = int(arc_length / 3) + 1 
    step_length = arc_length / n 
    step_angle = float(angle) / n 
    polyline(t, n, step_length, step_angle)

def flower(t, r, angle):
   c= 2*r*mt.sin(mt.radians(angle))
   x= r-r*mt.cos(mt.radians(angle))
   o= mt.degrees(mt.atan(4*x/c))
   n= int(360/o)
   for i in range(n):
     arc(t, r,angle)
     t.left(180 - angle)
     arc(t, r,angle)
     t.right(o)

print()

#x= input('Digite uma cor entre: "white", "yellow", "orange", "red", "green", "blue", "purple", "grey", "black": ')

#print()

#y= int(input('Digite uma grossura para o desenho: '))

#print()

def ex1_4():
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    polygon(T, 4, 100)
#ex1_4()

def ex1_5():
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    T.left(180 - 36/2)
    polyline(T, 5, 100, 180 - 36)
#ex1_5()

def ex1_6():
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    T.left(90)
    T.penup()
    T.forward(300)
    T.pendown()
    T.left(90 - 36/2)
    n= 5
    for i in range(n):
        polyline(T, 5, 100, 180 - 36)
        T.left(90 + 36/2)
        T.penup()
        T.forward(150)
        T.pendown()
        T.left(270 - 36/2)
#ex1_6()

#def ex1_2():
#   flower(T, 100, 80)

def ex2_2(x, n):
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    a= 360/n
    b= 180*(n-2)/n
    r= int(x/(2*mt.sin(mt.radians(a/2))))
    for i in range(n):
        T.forward(r)
        T.left(a + b/2)
        T.forward(x)
        T.left(180 + a + b/2)
        T.penup()
        T.forward(-r)
        T.pendown()
#ex2_2(100, 3)

def ex2_2_2(x):
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    n= 1000
    a= 360/n
    b= 180*(n-2)/n
    r= int(x/(2*mt.sin(mt.radians(a/2))))
    for i in range(n):
        T.forward(r)
        T.left(a + b/2)
        T.forward(x)
        T.left(180 + a + b/2)
        T.penup()
        T.forward(-r)
        T.pendown()
#ex2_2_2(1)

#def ex1_2():
#   flower(T, 100, 80)

def ex2_5():
    T.initializeTurtle()
    T.speed(10)
    #T.color(x)
    #T.width(y)
    n= 260
    a= 0.05
    b= 0.0005
    t= 0.0
    for i in range(n):
        T.forward(5)
        dt = 1 / (a + b*t)
        T.left(dt)
        t += dt

#ex2_5()
# Out:
# Aluno - Arthur Henrique Silva
# Aula - 5
#
# ...
