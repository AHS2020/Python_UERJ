# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 5.1

print('Esse programa é referente à aula 5.1 de python da uerj 2021/01')

print(' ')
print(' ')

input("Pressione Enter para continuar!")

print(' ')
print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('Modifique o programa da tartaruga (primeiro exemplo) para que, antes de')
print('criar a janela, ele solicite que o usuário insira a cor de fundo desejada.')
print('Ele deve armazenar as respostas do usuário em uma variável e modificar a')
print('cor da janela de acordo com os desejos do usuário.')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

import turtle            
jn = turtle.Screen()      
joana = turtle.Turtle()    

prompt = 'Digite o nome de uma cor dentre as encontradas em: "http://www.tcl.tk/man/tcl8.4/TkCmd/colors.html", para ser a tela de fundo. \n'

jn.bgcolor(input(prompt)) 
joana.forward(50)         
joana.left(90)             
joana.forward(30)          

jn.mainloop()             

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Faça modificações similares para permitir que o usuário mude a cor da tartaruga')
print('durante a execução do programa, faça o mesmo para a largura da caneta da tartaruga.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle                     
jn = turtle.Screen()               
joana = turtle.Turtle()            

print('As cores utilizadas aqui são encontradas em: "http://www.tcl.tk/man/tcl8.4/TkCmd/colors.html".')

print(' ')
print(' ')

prompt1 = 'Digite o nome de uma cor para ser a cor de fundo da janela: \n'
prompt2 = 'Digite o nome de uma cor diferente da anterior para ser a cor da tartaruga: \n'
prompt3 = 'Digite um numerointeiro para ser a largura da caneta: \n'

jn.bgcolor(input(prompt1))
print(' ')        
joana.color(input(prompt2))
print(' ')        
joana.pensize(int(input(prompt3))) 

joana.forward(50)                 
joana.left(90)                   
joana.forward(30)                
 
jn.mainloop()                    

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 3

print('Exercício 3')

print(' ')

print('Investigue os métodos e tipos do módulo turtle')

print(' ')

input("Pressione Enter imprimir a resposta!")

print('Leia o site "https://docs.python.org/3/library/turtle.html"')                  

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 4

print('Exercício 4')

print(' ')

print('Desenhe um quadrado, usando a forma de tartaruga, ao invés da flecha,')
print('para desenhar e mude a velocidade com que a tartaruga faz o desenho.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle                     
jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

joana.up()
joana.left(180)
joana.forward(50)
joana.left(90)
joana.forward(50)
joana.left(90)
joana.down()

for i in range(4):
    joana.forward(100)
    joana.left(90)
    
jn.mainloop()

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 5

print('Exercício 5')

print(' ')

print('Sabendo que o ângulo interno da ponta de uma estrela de 5 pontas é de')
print('36 graus, desenhe uma estrela em uma janela.') 

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

l = 100

a = (l/2)/math.tan(math.radians(36))

L = l*math.sqrt(2*(1-math.cos(math.radians(108))))

joana.up()
joana.left(180)
joana.forward(l/2)
joana.left(90)
joana.forward(a)
joana.left(90)
joana.down()

joana.left((180-36)/2)

for i in range(5):
    joana.forward(L)
    joana.left(180+36)
    
jn.mainloop()

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 6

print('Exercício 6')

print(' ')

print('Sabendo o ângulo interno da ponta de uma estrela, desenhe quatro')
print('estrelas em uma janela, com uma certa distância entre elas.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)

l = 100

a = (l/2)/math.tan(math.radians(36))

L = l*math.sqrt(2*(1-math.cos(math.radians(108))))

joana.up()
joana.left(180)
joana.forward(2*l)
joana.left(90)
joana.forward(a)
joana.left(90)
joana.down()

joana.left((180-36)/2)

for i in range(5):
    joana.forward(L)
    joana.left(180+36)

joana.right((180-36)/2)

joana.up()
joana.forward(2*l)
joana.down()

joana.left((180-36)/2)

for i in range(5):
    joana.forward(L)
    joana.left(180+36)

joana.right((180-36)/2)

joana.up()
joana.right(90)
joana.forward(2*l)
joana.left(90)
joana.down()

joana.left((180-36)/2)

for i in range(5):
    joana.forward(L)
    joana.left(180+36)

joana.right((180-36)/2)

joana.up()
joana.right(180)
joana.forward(2*l)
joana.left(180)
joana.down()

joana.left((180-36)/2)

for i in range(5):
    joana.forward(L)
    joana.left(180+36)

joana.right((180-36)/2)

jn.mainloop() 


print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
