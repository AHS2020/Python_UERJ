# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 7.1

print('Esse programa é referente à aula 7.1 de python da uerj 2021/01')

print(' ')
print(' ')

input("Pressione Enter para continuar!")

print(' ')
print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('A conjectura de Collatz, diz que "Todos os inteiros positivos irão')
print('eventualmente convergir para 1 usando as regras do Collatz". Faça um')
print('programa que verifique a conjectura de Collatz para alguns valores.')
print('As regras de Collatz são:')
print('   Dado um número n:')
print('     se n for par, divida-o por 2;')
print('     se n for ímpar, atualize-o para 3*n + 1;')
print('     repetir até chegar ao valor 1.')


print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

n=int(input("Digite um número inteiro maior que 1! \n"))

while n < 2:
		print('O número', n, 'não pode ser utilizado.')
		n = int(input("Digite um número inteiro maior que 1! \n"))

while n:
  if n % 2==0:
    print(n, "é par")
    break
  else:
    print(n, "é ímpar")
    n= 3*n +1

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Modifique a função counter para contar o número de vezes que os dígitos 0')
print('e 5 aparecem em um dado número n. Por exemplo, n = 10568, tem 2 dígitos 0')
print('ou 5.')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

n = 10568
c = 0

for f in [1, 10, 100, 1000, 10000]:
  i = n // f % 10
  if i == 0:
    c = c + 1
  elif i== 5:
    c = c + 1

if c == 0:
  print('Não existem digitos 0 ou 5 nesse número!')

elif c == 1:
  print('Existem apenas 1 digito 0 ou 5 nesse número!')

else:
    print('Existem', c,'digitos 0 ou 5 nesse número!')

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 3

print('Exercício 3')

print(' ')

print('Encapsule e generalize a seguinte declaração:') 
print('   for i in [12, 16, 17, 24, 29]')
print('       if i % 2==1: #If the nimber is odd') 
print('           break    # ... immediately exit the loop')
print('       print(i)')
print('   print("done")')

print(' ')

input("Pressione Enter imprimir a resposta!")

def impar_par (x):
  for i in x:
    if i % 2 == 1:      
      print(i, 'é impar')
    elif i % 2 == 0: 
      print(i, 'é par')
    print(' ')

x = [12, 16, 17, 24, 29, 30]

impar_par(x)

print(' ')

print("Concluido")

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 4

print('Exercício 4')

print(' ')

print('O método de Newton para raiz quadrada. Suponha que você queira calcular a')
print('raiz quadrada de n. Se você começar com quase qualquer aproximação, poderá')
print('calcular uma aproximação melhor (mais próxima da resposta real) com a')
print('seguinte fórmula: melhor = (approx + n/approx)/2')
print(' ')
print('Usando um loop e repetindo esta fórmula até que a melhor aproximação se')
print('aproxime o suficiente da anterior (este "suficiente" é arbitrario: podemos')
print('considerar uma diferença de 0,001), escreva uma função para calcular a')
print('raiz quadrada utilizando o método de Newton.')
print(' ')
print('Esse é um exemplo de repetição indefinida. Com qual tipo de loop você deve')
print('escrever o seu programa?')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

def r_q(n):
    ap = n/2.0
    while True:
    	m = (ap + n/ap)/2.0
    	if abs(ap - m) == 0:
    		return m
    	ap = m

n = int(input('Digite o número que você deseja saber a raiz quadrada: '))

print(' ')

print('A raiz quadrada de', n, 'é:', r_q(n))

print('Loop com while')

print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
# Out:
# Esse programa é referente à aula 7.1 de python da uerj 2021/01
#
#
# Pressione Enter para continuar!
#
#
# Exercício 1
#
# A conjectura de Collatz, diz que "Todos os inteiros positivos irão
# eventualmente convergir para 1 usando as regras do Collatz". Faça um
# programa que verifique a conjectura de Collatz para alguns valores.
# As regras de Collatz são:
#    Dado um número n:
#      se n for par, divida-o por 2;
#      se n for ímpar, atualize-o para 3*n + 1;
#      repetir até chegar ao valor 1.
#
# Pressione Enter imprimir a resposta!
#
# Digite um número inteiro maior que 1!
# 10
# 10 é par
#
#
# Pressione Enter para avançar para o próximo exercício!
#
#
# Exercício 2
#
# Modifique a função counter para contar o número de vezes que os dígitos 0
# e 5 aparecem em um dado número n. Por exemplo, n = 10568, tem 2 dígitos 0
# ou 5.
#
# Pressione Enter imprimir a resposta!
#
# Existem 2 digitos 0 ou 5 nesse número!
#
#
# Pressione Enter para avançar para o próximo exercício!
#
#
# ...
