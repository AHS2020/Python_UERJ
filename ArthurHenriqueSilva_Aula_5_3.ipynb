# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 5.3

print('Esse programa é referente à aula 5.3 de python da uerj 2021/01')

print(' ')
print(' ')

input("Pressione Enter para continuar!")

print(' ')
print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('Escreva um conjunto apropriadamente geral de funções que possam desenhar')
print('flores como na Figura abaixo.') 

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

def petala (t, r, ang):

  for i in range(ang):
    t.left(1)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/360))))

  t.left(180 - ang)

  for i in range(ang):
    t.left(1)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/360))))
  
  t.left(180 - ang)

def flor (t, r, ang, n):
  
  for i in range(n):
    petala (t, r, ang)
    t.right (360/n)
  
flor (joana, 100, 30, 10)

jn.mainloop()            

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Escreva um conjunto apropriadamente geral de funções que podem desenhar')
print('formas como na figura.')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

def polygon (t, n, l):
  
  a = (l/2)/math.tan(math.pi/n)
  
  joana.up()
  t.left(180)
  t.forward(l/2)
  t.left(90)
  t.forward(a)
  t.left(90)
  t.down()

  for i in range(n):
    t.forward(l)
    t.left(360/n)
    t.left(((n-2)*180)/(2*n))
    t.forward(l/(math.sqrt(2*(1-math.cos((2*math.pi)/n)))))
    t.left(180)
    t.up()
    t.forward(l/(math.sqrt(2*(1-math.cos((2*math.pi)/n)))))
    t.down()
    t.left(((n-2)*180)/(2*n))
    t.left(360/n)
  
  joana.up()
  t.left(90)
  t.forward(a)
  t.right(90)
  t.forward(l/2)
  t.down()
  
polygon(joana, 10, 75)
jn.mainloop()

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 3

print('Exercício 3')

print(' ')

print('Adicione instruções para desenhar o talo e folha da flor. Faça a')
print('refatoração apropriada para a interface da flor completa ficar "limpa".')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

def petala (t, r, ang):

  for i in range(ang):
    t.left(1)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/360))))

  t.left(180 - ang)

  for i in range(ang):
    t.left(1)
    t.forward(r*math.sqrt(2*(1-math.cos((2*math.pi)/360))))
  
  t.left(180 - ang)

def flor (t, r, ang, n, c):
  
  for i in range(n):
    petala (t, r, ang)
    t.right (360/n)
  
  t.right(90)
  t.forward(3*c/5)
  t.left(90)
  petala(t,  r/2, ang)
  t.right(90)
  t.forward(2*c/5)
  t.left(180)
  t.up()
  t.forward(c)
  t.down()
  t.right(90)
  
flor (joana, 100, 30, 5,100)

jn.mainloop()    

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 4

print('Exercício 4')

print(' ')

print('As letras do alfabeto podem ser construídas a partir de um número moderado')
print('de elementos básicos, como linhas verticais e horizontais e algumas curvas.')
print('Projete um alfabeto que possa ser desenhado com um número mínimo de') 
print('elementos básicos e depois escreva funções que desenhem as letras.')
print('  Você deve escrever uma função para cada letra, com os nomes draw_a_,')
print('  _draw_b_, etc., e colocar suas funções em um arquivo chamado')
print('  letters.py.')



print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

print('Não foi feito')

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')

# Exercício 5

print('Exercício 5')

print(' ')

print('Leia sobre espirais em "http://en.wikipedia.org/wiki/Spiral"; em seguida,')
print('escreva um programa que desenhe uma espiral arquimediana (ou um dos')
print('outros tipos).')

print(' ')

input("Pressione Enter imprimir a resposta!")

import turtle
import math

jn = turtle.Screen()               
joana = turtle.Turtle()     
joana.shape("turtle")

jn.bgcolor("white")
joana.color("blue violet")
joana.pensize(3)
joana.speed(10)

import turtle

def draw_spiral(t, n, l=3, a=0.1, b=0.0002):
    theta = 0.0

    for i in range(n):
        t.fd(l)
        dtheta = 1 / (a + b * theta)

        t.lt(dtheta)
        theta += dtheta

draw_spiral(joana, n=500)

jn.mainloop()     

print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
