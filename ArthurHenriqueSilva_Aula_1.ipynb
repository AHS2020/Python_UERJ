# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 1

print('Esse programa é referente à aula 1 de python da uerj 2021/01')

print(' ')
print(' ')
print(' ')

input("Pressione Enter para continuar!")

print(' ')
print(' ')
print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('Escreva na tela do modo prompt: "mundo, mundo, vasto mundo"')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

print("mundo, mundo, vasto mundo")

print(' ')
print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')
print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Imprima na tela a documentação da função print')

print(' ')

input("Pressione Enter imprimir a resposta!")

print(' ')

help('print') # Resposta do exercício 2

print(' ')
print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!")

print(' ')
print(' ')
print(' ')

# Exercício 3

print('Exercício 3')

print(' ')

print('Inicie o interpretador Python e use-o como uma calculadora. A sintaxe do Python para') 
print('operações matemáticas é quase igual à notação matemática padrão:')
print('    adição: +')
print('    subtração: -')
print('    divisão: /')
print('    multiplicação: *')
print('Se você fizer uma corrida de 10 quilômetros em 43 minutos e 30 segundos, qual será ')
print('seu tempo médio por milha? Qual é a sua velocidade média em milhas por hora? (Dica:') 
print('há 1,61 quilômetros em uma milha).')

print(' ')

input("Pressione Enter iniciar a resposta!")

print(' ')

# Resposta do exercício 3

dkm = float(input('Insira a distância em quilometros:  '))

tmin = float(input('Insira o tempo decorrido em minutos utilizando "." no lugar da vírgula:  '))

dmi = dkm/1.61

Tmed = tmin/dmi

th = tmin/60

Vmed = dmi/th

print('')

print(f'Tempo médio por milha =  {Tmed:.2f} minutos/milha')

print('')

print(f'Velocidade média =  {Vmed:.2f} milhas/hora')

print(' ')
print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
print(' *Fim do programa* ')
# Out:
# Esse programa é referente à aula 1 de python da uerj 2021/01
#
#
#
# Pressione Enter para continuar!
#
#
#
# Exercício 1
#
# Escreva na tela do modo prompt: "mundo, mundo, vasto mundo"
#
# Pressione Enter imprimir a resposta!
#
# mundo, mundo, vasto mundo
#
#
#
# Pressione Enter para avançar para o próximo exercício!
#
#
#
# Exercício 2
#
# Imprima na tela a documentação da função print
#
# Pressione Enter imprimir a resposta!
#
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
#
#
#
#
# ...
