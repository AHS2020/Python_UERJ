# %% [markdown]
# <a href="https://colab.research.google.com/github/AHS2020/Python_UERJ/blob/master/ArthurHenriqueSilva_Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Aula 3

print('Esse programa é referente à aula 3 de python da uerj 2021/01')

print(' ')
print(' ')

input("Pressione Enter para continuar!\n")

print(' ')

# Exercício 1

print('Exercício 1')

print(' ')

print('Crie uma funcão que tome um argumento e imprima o valor e o tipo dele.')

print(' ')

input("Pressione Enter imprimir a resposta!\n")

def arg_print_type():
    prompt = 'Digite um número ou uma palavra.\n'
    x = input(prompt)
    try:
        float(x)
        f = float(x)
        if f==int(f):
          f = int(x)
          print(f, type(f))
        else:
          print(f, type(f))

    except:
        print(x, type(x))

arg_print_type()
print(' ')
arg_print_type()
print(' ')
arg_print_type()

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!\n")

print(' ')

# Exercício 2

print('Exercício 2')

print(' ')

print('Crie uma função que calcule e imprima velocidade media de um objeto')
print('a partir de uma posição inicial, posição final e o tempo transcorrido')
print('para um objeto em MRU. Também crie uma funcão que calcule e imprima a')
print('velocidade de um objeto a partir da aceleração constante e o tempo')
print('(MRUA) (p.ex. queda livre).')

print(' ')

input("Pressione Enter imprimir a resposta!\n")

prompt = 'Digite a posição inicial em metros.\n'
pi = float(input(prompt))
print(' ')
prompt = 'Digite a posição final em metros.\n'
pf = float(input(prompt))
print(' ')
prompt = 'Digite tempo transcorrido em segundos.\n'
t = float(input(prompt))
print(' ')

def MRU(x1, x2, x3):
    Vm = (x1-x2)/x3
    print(f'Velocidade média = {Vm:.2f} m/s')

MRU(pf, pi, t)
print(' ')

prompt = 'Digite a acelaração em metros por segundo ao quadrado.\n'
a = float(input(prompt))
print(' ')
prompt = 'Digite tempo em segundos.\n'
t = float(input(prompt))
print(' ')

def MRUA (x1, x2):
    V = x1*x2
    print(f'Velocidade = {V:.2f} m/s')

MRUA (a, t)

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!\n")

print(' ')

# Exercício 3

import math as mt

print('Exercício 3')

print(' ')

print('Crie uma funcão para calcular o ángulo zenital do sol tomando') 
print('como argumento as medidas da altura e o comprimento da sombra.')

print(' ')

input("Pressione Enter imprimir a resposta!\n")

prompt = 'Digite a altura do objeto em metros.\n'
h = float(input(prompt))
print(' ')
prompt = 'Digite o comprimento da sombra em metros.\n'
s = float(input(prompt))
print(' ')

def zenit(x1, x2):
    ar = mt.atan(x2/x1)
    ag = (180*ar)/mt.pi
    zg1 = (180 - ag)
    zg2 = int(zg1)
    zm1 = (zg1 - zg2)*60
    zm2 = int(zm1)
    zs1 = (zm1 - zm2)*60
    zs2 = int(zs1)
    print(f'Ângulo zenital = {zg2}° {zm2}'"'",f'{zs2}"')

zenit(h, s)

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!\n")

print(' ')

# Exercício 4

print('Exercício 4')

print(' ')

print('Crie uma função que faça a conversão de uma medida inicialmente em') 
print('milhas para kilometros, e outra para o inverso; uma de horas para')
print('minutos, e o inverso. Utilize estas funções para resolver novamente') 
print('o primeiro exercício da semana passada (da corrida).')
print(' ')
print('Se você fizer uma corrida de 10 quilômetros em 43.5 minutos, qual será ')
print('seu tempo médio por milha? Qual é a sua velocidade média em milhas por hora? (Dica:') 
print('há 1,61 quilômetros em uma milha).')
print(' ')
print('Se uma pessoa demora 30 minutos em 4 milhas, qual velocidade media em km/h ? e o')
print('tempo medio por kilometro?')

print(' ')

input("Pressione Enter imprimir a resposta!\n")

def mi_to_km(xmi):
    xkm = xmi*1.61
    print(f'Distância =  {xkm} km')

def km_to_mi(xkm):
    xmi = xkm/1.61
    print(f'Distância =  {xmi} mi')

def h_to_min(xh):
    xmin = xh*60
    print(f'Tempo =  {xmin} min')

def min_to_h(xmin):
    xh = xmin/60
    print(f'Tempo =  {xh} h')

def min_mi(min,mi):
    Tmed = min/mi
    print(f'Tempo médio por milha =  {Tmed:.2f} min/mi')

def mi_h(mi,h):
    Vmed = mi/h
    print(f'Velocidade média =  {Vmed:.2f} mi/h')

def km_h(km,h):
    Vmed = km/h
    print(f'Velocidade média =  {Vmed:.2f} km/h')


prompt = 'Digite a distância em quilometros:\n'
dkm = float(input(prompt))
print(' ')

prompt = 'Digite o tempo decorrido em minutos:\n'
tmin = float(input(prompt))
print(' ')
    
km_to_mi(dkm)
print(' ')

prompt = 'Repita a distância em milhas:\n'
dmi = float(input(prompt))
print(' ')

min_mi(tmin,dmi)

print(' ')

min_to_h(tmin)

print(' ')

prompt = 'Repita a tempo em horas:\n'
th = float(input(prompt))
print(' ')

mi_h(dmi,th)

print(' ')

prompt = 'Digite a distância em milhas:\n'
dmi2 = float(input(prompt))
print(' ')

prompt = 'Digite o tempo decorrido em minutos:\n'
tmin2 = float(input(prompt))
print(' ')

mi_to_km(dmi2)

print(' ')

prompt = 'Repita a distância em quilometros:\n'
dkm2 = float(input(prompt))
print(' ')

min_to_h(tmin2)

print(' ')

prompt = 'Repita a tempo em horas:\n'
th2 = float(input(prompt))
print(' ')

km_h(dkm2, th2)

print(' ')
print(' ')

input("Pressione Enter para avançar para o próximo exercício!\n")

print(' ')

# Exercício 5

from numpy import pi

print('Exercício 5')

print(' ')

print('Crie funções para calcular os outros exemplos das aulas anteriores:') 
print('volume de uma esfera e distancia entre pontos de máximos de difração.') 
print('Decida quais serão os argumentos e o valor retornado.')

print(' ')

input("Pressione Enter imprimir a resposta!\n")

prompt = 'Digite o raio da esfera:\n'
r = float(input(prompt))
print(' ')

def v_esfera(r):
    V = (4/3)*(pi)*(r**3)
    print(f'Volume = {V:.2f}')

v_esfera(r)

print(' ')

prompt = 'Digite o comprimento de onda \u03BB em nm:\n'
l = float(input(prompt))*(10**(-9))
print(' ')

prompt = 'Digite distância D do anteparo à fenda:\n'
D = float(input(prompt))
print(' ')

prompt = 'Digite o espaçamento d entre as fendas em mm:\n'
d = float(input(prompt))*(10**(-3))
print(' ')

def deltay(l, D, d):
    dy = (l*D*(10**3))/d
    print(f'\u0394y = {dy:.2f} mm')

deltay(l, D, d)

print(' ')
print(' ')

print(' *Fim do programa* ')
print(' *Fim do programa* ')
# Out:
# Esse programa é referente à aula 3 de python da uerj 2021/01
#
#
# Pressione Enter para continuar!
#
#
# Exercício 1
#
# Crie uma funcão que tome um argumento e imprima o valor e o tipo dele.
#
# Pressione Enter imprimir a resposta!
#
# Digite um número ou uma palavra.
# Word
# Word <class 'str'>
#
# Digite um número ou uma palavra.
# 15
# 15 <class 'int'>
#
# Digite um número ou uma palavra.
# 1.5
# 1.5 <class 'float'>
#
#
# Pressione Enter para avançar para o próximo exercício!
#
#
# Exercício 2
#
# Crie uma função que calcule e imprima velocidade media de um objeto
# a partir de uma posição inicial, posição final e o tempo transcorrido
# para um objeto em MRU. Também crie uma funcão que calcule e imprima a
# velocidade de um objeto a partir da aceleração constante e o tempo
# (MRUA) (p.ex. queda livre).
#
# Pressione Enter imprimir a resposta!
#
# Digite a posição inicial em metros.
# 10
#
# Digite a posição final em metros.
# 25
#
# Digite tempo transcorrido em segundos.
# 3
#
# ...
